# %%
def Name(n="Kunal"):
    return f"Hello my name is {n}"


Name()
# Out:
# 'Hello my name is Kunal'

# %%
def even_odd(data):
    if data%2==0:
        print(f"{data} is Even")
    else:
        print(f"{data} is odd")


idata=eval(input("Enter the number:"))
even_odd(idata)
# Out:
# 5 is odd

# %%
def ar(*arg):
    return arg

ar(1,2,3,3,4,4,5,6,"kunal")
# Out:
# (1, 2, 3, 3, 4, 4, 5, 6, 'kunal')

# %%
def ar(**ar):
    for key,values in ar.items():
        print(f"{key}:{values}")

ar(name="Kunal",age="Rohit")
# Out:
# name:Kunal
# age:Rohit

# %%
def print_details(*args,**kwargs):
    for val in args:
        print(f" Positional argument: {val}")
    for key, value in kwargs.items():
        print(f"Key Argument : {key}:{value}")

print_details(1,2,3,4,5,"kunal",name="Rohit",marks=45)
# Out:
#  Positional argument: 1
#  Positional argument: 2
#  Positional argument: 3
#  Positional argument: 4
#  Positional argument: 5
#  Positional argument: kunal
# Key Argument : name:Rohit
# Key Argument : marks:45

# %% [markdown]
# # Example Temperature convertion

# %%
def convert_temprature(temp,unit):
    if unit=="C":
        return temp * 9/5 + 32
    elif unit=="F":
        return (temp-32) * 5/9
    else:
        None
    

print(convert_temprature(25,'C'))

print(convert_temprature(77,'F'))
# Out:
# 77.0
# 25.0

# %% [markdown]
# # password strenght checker

# %%
def is_strong_password(password):
    if len(password)<8:
        return False
    if not any(char.isdigit() for char in password):
        return False
    if not any(char.islower() for char in password):
        return False
    if not any(char.isupper() for char in password):
        return False
    if not any(char in '!@#$%^&*()_+' for char in password):
        return False
    return True
is_strong_password("Kunal@13")
# Out:
# True

# %% [markdown]
# # Calculate the total cost of items in shopping cart

# %%
def calculate_total_cost(cart):
    # total_cost=0
    for i in cart:
        print(i["price"]*i["quantity"])
        # total_cost+= i["price"]*i["quantity"]
    # return total_cost


cart=[
    {"name":"Apple","price":0.5,"quantity":4},
    {"name":"Banana","price":0.3,"quantity":6},
    {"name":"Orange","price":0.7,"quantity":3}
]
calculate_total_cost(cart)
# Out:
# 2.0
# 1.7999999999999998
# 2.0999999999999996

# %%
def square_data(s):
    return s**2

data=[1,2,3,4,5,6]
# print(square_data(data))

print(list(map(square_data,data)))
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
def celsius_to_fahrenheit(C):
    Fahrenheit = (9/5 * C) + 32
    return(float(Fahrenheit))

celsius_to_fahrenheit(40)
# Out:
# 104.0

# %%
def calculate_distance(speed, time):
    distance = speed * time
    return (float(distance)) 

calculate_distance(60,2)
calculate_distance(50.5,1.5)
# Out:
# 75.75

# %%
def calculate_lift_rounds(n, capacity):
    """
    Function to calculate the number of rounds the lift needs to cover.
    
    Parameters:
    n (int): Total number of people.
    capacity (int): Maximum number of people the lift can carry in one round.
    
    Returns:
    int: The number of rounds required to transport all people to the top floor.
    """
    rounds=round(n//capacity) + 1
    return rounds
calculate_lift_rounds(10,3)
calculate_lift_rounds(7,4)
# Out:
# 2

# %%
def calculate_y(slope, intercept, x):
    """
    Function to calculate the value of y using the slope-intercept form of a line.
    
    Parameters:
    slope (float): The slope of the line.
    intercept (float): The y-intercept of the line.
    x (float): The value of x for which y needs to be calculated.
    
    Returns:
    float: The calculated value of y.
    """
    y=(slope*(x)) + intercept
    return(float(y))

calculate_y(2,3,4)
calculate_y(1.5,-2,2)
# Out:
# 1.0

# %%
def sum_list(numbers):
    return sum(numbers)
            
   
number=[1, 2, 3, 4, 5]
sum_list(number)
# Out:
# 15

# %%
def sum_list(numbers):
    sum=0
    for i in numbers:
        sum =sum+i
    return sum
   
number=[1, 2, 3, 4, 5]
sum_list(number)
# Out:
# 15

# %%
def find_largest(numbers):
    temp = numbers[0]   # start with first element

    for i in numbers:
        if i > temp:
            temp = i

    return temp


numbers = [-5, -10, -2, -1, -7]
print(find_largest(numbers))  # Output: -1
# Out:
# -1

# %%
def remove_duplicates(lst):
    list2=[]
    for i in lst:
        if i not in list2:
            list2.append(i)
        
    return(list2)
lst1 = [1, 2, 2, 3, 4, 4, 5]
lst2 = [4, 5, 5, 4, 6, 7]
a=remove_duplicates(lst1)
b=remove_duplicates(lst2)
print(a)
print(b)
# Out:
# [1, 2, 3, 4, 5]
# [4, 5, 6, 7]

# %%
def check_unique(lst):
    if lst == set(lst):
        return True
    else:
        return False
lst = [1, 2, 3, 4, 5]

# %%
def count_even_odd(lst):
    
    for i in lst:
        if i%2==0:
            count_even+=1
        else:
            count_odd+=1
    print( count_even,count_odd)

lst = [1, 2, 3, 4, 5]

# %%
def is_subset(lst1, lst2):
    return set(lst1).issubset(set(lst2))

lst1 = [1, 2, 3]
lst2 = [1, 2, 3, 4, 5]

print(is_subset(lst1, lst2))
# Out:
# True

# %%
def max_consecutive_diff(lst):
    max_diff = 0
    
    for i in range(len(lst) - 1):
        diff = abs(lst[i] - lst[i + 1])
        
        if diff > max_diff:
            max_diff = diff
            
    return max_diff


# Test cases
print(max_consecutive_diff([1, 7, 3, 10, 5]))   
print(max_consecutive_diff([10, 11, 15, 3]))
# Out:
# 7
# 12

# %%
def merge_two_sorted_lists(list1, list2):
    merged = []
    i, j = 0, 0
    while i < len(list1) and j < len(list2):
        if list1[i] < list2[j]:
            merged.append(list1[i])
            i += 1
        else:
            merged.append(list2[j])
            j += 1
    merged.extend(list1[i:])
    merged.extend(list2[j:])
    return merged
  
list1 = [1, 3, 5]
list2 = [2, 4, 6]
merge_two_sorted_lists(list1, list2)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
def merge_two_sorted_lists(list1, list2):
    return list1+list2
list1 = [1, 3, 5]
list2 = [2, 4, 6]
sorted(merge_two_sorted_lists(list1, list2))
# Out:
# [1, 2, 3, 4, 5, 6]
