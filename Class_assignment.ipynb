# %% [markdown]
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Update Marks
# 5. Delete Student
# 6. Exit

# %%
class School:
    def __init__(self,roll_no,name,marks):
        self.roll_no=roll_no,
        self.name=name,
        self.marks=marks,

students=[]

def add():
    roll_no =int(input("Enter the Roll number: "))
    name =input("Enter the Roll Name: ")
    marks=int(input("Enter the Roll number: "))
    students.append(students(roll_no,name,marks))
    print("Data Added")

def view_data():
    for student in students:
        print(student.roll_no,student.name,student.marks)

def search_student():
    r = int("Enter the roll number you need to Search:-" )
    for student in students:
        if student.roll_no == r:
            print(student.roll_no,student.name,student.marks)
            return
    print("Data Not found")

def update_marks():
    r = int(input("Enter roll: "))
    for student in students:
        if student.roll == r:
            student.marks = int(input("New marks: "))
            print("Marks has been Updated")
            return
    print("Data Not found")


def delete_student():
    r = int(input("Enter roll: "))
    for s in students:
        if s.roll == r:
            students.remove(s)
            print("Deleted")
            return
    print("Not found")

while True:
    print("\n1.Add 2.View 3.Search 4.Update 5.Delete 6.Exit")
    ch = int(input("Choice: "))

    if ch == 1:
        add_student()
    elif ch == 2:
        view_students()
    elif ch == 3:
        search_student()
    elif ch == 4:
        update_marks()
    elif ch == 5:
        delete_student()
    elif ch == 6:
        break
# Out:
# Welcome to Add Student Section
# Student added successfully!
# {'roll_number': 2, 'name': 'prasad', 'marks': 56}
