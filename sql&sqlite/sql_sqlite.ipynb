# %%
import sqlite3

# %%
connection=sqlite3.connect('kunal.db')
connection

# %%
cursor = connection.cursor()  
cursor.execute('create table if not exists users(id integer primary key, name text, age integer)')
connection.commit()

# %%
cursor.execute("INSERT INTO users VALUES (?, ?, ?)", (1, "Amit", 25))

# %%
cursor.execute("INSERT INTO users VALUES (?, ?, ?)", (2, "kuna", 31))

# %%
cursor.execute("INSERT INTO users VALUES (?, ?, ?)", (3, "rohit", 36))

# %%
cursor.execute('SELECT * FROM users')
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (1, 'Amit', 25)
# (2, 'Kunal', 31)
# (3, 'Rohit', 36)

# %%
cursor.execute("""
update users set name = 'Rohit' where id = '3'""")

# %%
import sqlite3

## Working With Sales Data
# Connect to an SQLite database
connection = sqlite3.connect('sales_data.db')
cursor = connection.cursor()

# Create a table for sales data
cursor.execute('''
CREATE TABLE IF NOT EXISTS sales (
    id INTEGER PRIMARY KEY,
    date TEXT NOT NULL,
    product TEXT NOT NULL,
    sales INTEGER,
    region TEXT
)
''')
# Insert data into the sales table
sales_data = [
    (1, '2023-01-01', 'Product1', 100, 'North'),
    (2, '2023-01-02', 'Product2', 200, 'South'),
    (3, '2023-01-03', 'Product1', 150, 'East'),
    (4, '2023-01-04', 'Product3', 250, 'West'),
    (5, '2023-01-05', 'Product2', 300, 'North')
]
connection.commit()

# %%
cursor.executemany('INSERT INTO sales VALUES (?, ?, ?, ?, ?)', sales_data)
connection.commit()

# %%
cursor.execute('SELECT * FROM sales')
rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 cursor.execute('SELECT * FROM sales')
#       2 rows = cursor.fetchall()
#       3 for row in rows:
#
# ProgrammingError: Cannot operate on a closed database.

# %%
connection.close()
