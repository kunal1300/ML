# %%
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\kunal\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text = "Hello!!! I am LearNing Data SciEnce And LovIng It"
text=text.lower()
print(text)

text =text.translate(str.maketrans("","",string.punctuation))
print(text)

words = text.split()
print(words)

stop_words =set(stopwords.words('english'))
words = [word for word in words if word not in stop_words]
print(words)

stemmer =PorterStemmer()
words =[stemmer.stem(word)for word in words]
print(words)

#finl clean text
clean_text = " ".join(words)
print(clean_text)
# Out:
# hello!!! i am learning data science and loving it
# hello i am learning data science and loving it
# ['hello', 'i', 'am', 'learning', 'data', 'science', 'and', 'loving', 'it']
# ['hello', 'learning', 'data', 'science', 'loving']
# ['hello', 'learn', 'data', 'scienc', 'love']
# hello learn data scienc love

# %%
text = "wow !!! Data-Science is Awesome. I've been learning it since 2023, and honestly, It's super-interesting!!! #AI #ML"

text=text.lower()
print(text)

text =text.translate(str.maketrans("","",string.punctuation))
print(text)

words = text.split()
print(words)

stop_words =set(stopwords.words('english'))
words = [word for word in words if word not in stop_words]
print(words)

stemmer =PorterStemmer()
words =[stemmer.stem(word)for word in words]
print(words)

#finl clean text
clean_text = " ".join(words)
print(clean_text)
# Out:
# wow !!! data-science is awesome. i've been learning it since 2023, and honestly, it's super-interesting!!! #ai #ml
# wow  datascience is awesome ive been learning it since 2023 and honestly its superinteresting ai ml
# ['wow', 'datascience', 'is', 'awesome', 'ive', 'been', 'learning', 'it', 'since', '2023', 'and', 'honestly', 'its', 'superinteresting', 'ai', 'ml']
# ['wow', 'datascience', 'awesome', 'ive', 'learning', 'since', '2023', 'honestly', 'superinteresting', 'ai', 'ml']
# ['wow', 'datasci', 'awesom', 'ive', 'learn', 'sinc', '2023', 'honestli', 'superinterest', 'ai', 'ml']
# wow datasci awesom ive learn sinc 2023 honestli superinterest ai ml
